# %% [markdown]
# <a href="https://colab.research.google.com/github/minji25-hue/pyhsics/blob/20250319/Python_%EA%B8%B0%EC%B4%883.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=4
b=3

c=1
d=2
print(a/b)
print(c/d)

e=7
f=3
print(e//f)
print(e%f)
print(e**f)
# Out:
# 1.3333333333333333
# 0.5
# 2
# 1
# 343

# %%
quotient, remainder = divmod(5,2)
print(quotient, remainder)
# Out:
# 2 1

# %%
a=11+2
b=12-2
c=13+2
d=14/2
e=15**2
f=16//2
g=17%3
print(a,b,c,d,e,f,g)
# Out:
# 13 10 15 7.0 225 8 2

# %%
i=3
i+=3
print(i)
i -=3
print(i)
i*=2
print(i)
i/=2
print(int(i))
i=3
i%=2
print(i)
# Out:
# 6
# 3
# 6
# 3
# 1

# %%
a=10
b=3
print("10==3=>", a==b)
print("10 1=3 =>", a !=b)
print("10>3=>", a>b)
print("10>=3=>",a>=b)
print("10<3=>", a<b)
print("10<=3=>",a<=b)
# Out:
# 10==3=> False
# 10 1=3 => True
# 10>3=> True
# 10>=3=> True
# 10<3=> False
# 10<=3=> False

# %%
a=13
print(bin(a))
print(hex(a))
# Out:
# 0b1101
# 0xd

# %%
a=13
b=9
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)
# Out:
# 0b1101
# 0b1001
# 0b1001
# 9

# %%
a=12
b=8
print(bin(a))
print(bin(b))
print(bin(a|b))
print('')
print(a|b)
# Out:
# 0b1100
# 0b1000
# 0b1100
#
# 12

# %%
a=12
b=8
print('')
print(bin(a))
print(bin(b))
print(bin(a&b))
print('')
print(a&b)
# Out:
# 0b1100
# 0b1000
# 0b1000
#
# 8

# %%
print('')
print(bin(a))
print(bin(b))
print(bin(a|b))
print('')
print(a|b)
# Out:
# 0b1100
# 0b1000
# 0b1100
#
# 12

# %%
print('')
print(bin(a))
print(bin(b))
print(bin(a^b))
print('')
print(a^b)
# Out:
# 0b1100
# 0b1000
# 0b100
#
# 4

# %%
print('')
print(bin(a))
print(bin(~a))
# Out:
# 0b1100
# -0b1101
